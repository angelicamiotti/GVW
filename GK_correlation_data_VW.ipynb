# %%
import pandas as pd
import seaborn as sb

# %%
df = pd.read_excel("C:/Users/angel/OneDrive/Franca2022/POEC-Global-knowledge/pprojeto/pastas_finais/versao_normalise/vw_dados.xlsx")
df.head()
# Out:
#    Year                      Brand  Deliveries (thousand units)  \
# 0  2018  Volkswagen Passenger Cars                       6245.0
# 1  2017  Volkswagen Passenger Cars                       6230.0
# 2  2018                       Audi                       1818.0
# 3  2017                       Audi                       1882.0
# 4  2018                      Skoda                       1254.0
#
#    Vehicle sales(K)  Production(K)  Sales revenue (€ million)  \
# 0            3715.0         6297.0                    84585.0
# 1            3573.0         6317.0                    79186.0
# 2            1467.0         1871.0                    59248.0
# 3            1530.0         1879.0                    59789.0
# 4             957.0         1285.0                    17293.0
#
#    Operating result  Operating return on sales (%)
# 0            3239.0                          0.038
# 1            3301.0                          0.042
# ...

# %%
lucro=df['Operating result']
lucro
# Out:
# 0     3239.0
# 1     3301.0
# 2     4705.0
# 3     5058.0
# 4     1377.0
# 5     1611.0
# 6      254.0
# 7      191.0
# 8     -288.0
# 9       55.0
# 10    4110.0
# 11    4003.0
# 12     780.0
# 13     853.0
# 14    1346.0
# 15    1289.0
# 16       NaN
# 17       NaN
# 18     332.0
# 19     362.0
# 20     454.0
# 21    3785.0
# 22    2739.0
# 23    4509.0
# 24     756.0
# 25    1660.0
# 26    -339.0
# 27     445.0
# 28      20.0
# 29      65.0
# 30    4021.0
# 31    4210.0
# 32    -454.0
# 33     510.0
# 34     748.0
# 35    1506.0
# 36       NaN
# 37       NaN
# 38    -631.0
# 39     402.0
# 40    2647.0
# 41    2160.0
# 42    7622.0
# 43    5936.0
# 44     628.0
# 45    1083.0
# 46      33.0
# 47    -233.0
# 48       NaN
# 49       NaN
# 50    6423.0
# 51    5006.0
# 52     529.0
# 53      73.0
# 54       NaN
# 55       NaN
# 56    1583.0
# 57     161.0
# 58       NaN
# 59       NaN
# Name: Operating result, dtype: float64

# %%
lucro.hist(bins = 15)
# Out:
# <AxesSubplot: >

# %%
CorMatrix = df.corr()
sb.set(font_scale=0.7)   # set the font scale at 0.7
sb.heatmap(CorMatrix, annot=True, cmap="YlGnBu", cbar=False)
# Out:
# C:\Users\angel\AppData\Local\Temp\ipykernel_12356\3162952229.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   CorMatrix = df.corr()
# <AxesSubplot: >

# %%
df_audi = df[df['Brand'] == 'Audi']
df_audi
sb.set(font_scale=0.7)   # set the font scale at 0.7
sb.heatmap(CorMatrix, annot=True, cmap="YlGnBu", cbar=False)
# Out:
# <AxesSubplot: >

# %%
df_pass_car = df[df['Brand'] == 'Volkswagen Passenger Cars']
CorMatrix = df_pass_car.corr()
sb.set(font_scale=0.7)   # set the font scale at 0.7
sb.heatmap(CorMatrix, annot=True, cmap="YlGnBu", cbar=False)
# Out:
# C:\Users\angel\AppData\Local\Temp\ipykernel_12356\1939808375.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   CorMatrix = df_pass_car.corr()
# <AxesSubplot: >

# %%
df_skoda = df[df['Brand'] == 'Skoda']
CorMatrix = df_skoda.corr()
sb.set(font_scale=0.7)   # set the font scale at 0.7
sb.heatmap(CorMatrix, annot=True, cmap="YlGnBu", cbar=False)
# Out:
# C:\Users\angel\AppData\Local\Temp\ipykernel_12356\1315096505.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   CorMatrix = df_skoda.corr()
# <AxesSubplot: >

# %%
df_seat = df[df['Brand'] == 'SEAT']
CorMatrix = df_seat.corr()
sb.set(font_scale=0.7)   # set the font scale at 0.7
sb.heatmap(CorMatrix, annot=True, cmap="YlGnBu", cbar=False)
# Out:
# C:\Users\angel\AppData\Local\Temp\ipykernel_12356\116059351.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   CorMatrix = df_seat.corr()
# <AxesSubplot: >

# %%
df_bentley = df[df['Brand'] == 'Bentley']
CorMatrix = df_bentley.corr()
sb.set(font_scale=0.7)   # set the font scale at 0.7
sb.heatmap(CorMatrix, annot=True, cmap="YlGnBu", cbar=False)
# Out:
# C:\Users\angel\AppData\Local\Temp\ipykernel_12356\3133657253.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   CorMatrix = df_bentley.corr()
# <AxesSubplot: >

# %%
df_porsche = df[df['Brand'] == 'Porsche']
CorMatrix = df_porsche.corr()
sb.set(font_scale=0.7)   # set the font scale at 0.7
sb.heatmap(CorMatrix, annot=True, cmap="YlGnBu", cbar=False)
# Out:
# C:\Users\angel\AppData\Local\Temp\ipykernel_12356\917237844.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   CorMatrix = df_porsche.corr()
# <AxesSubplot: >

# %%
df_man = df[df['Brand'] == 'MAN']
CorMatrix = df_man.corr()
sb.set(font_scale=0.7)   # set the font scale at 0.7
sb.heatmap(CorMatrix, annot=True, cmap="YlGnBu", cbar=False)
# Out:
# C:\Users\angel\AppData\Local\Temp\ipykernel_12356\4066878981.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   CorMatrix = df_man.corr()
# <AxesSubplot: >

# %%
df_scania = df[df['Brand'] == 'Scania']
CorMatrix = df_scania.corr()
sb.set(font_scale=0.7)   # set the font scale at 0.7
sb.heatmap(CorMatrix, annot=True, cmap="YlGnBu", cbar=False)
# Out:
# C:\Users\angel\AppData\Local\Temp\ipykernel_12356\3942589106.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   CorMatrix = df_scania.corr()
# <AxesSubplot: >

# %%
#inutile.... que deux points 
df_traton = df[df['Brand'] == 'TRATON']
CorMatrix = df_traton.corr()
sb.set(font_scale=0.7)   # set the font scale at 0.7
sb.heatmap(CorMatrix, annot=True, cmap="YlGnBu", cbar=False)
# Out:
# C:\Users\angel\AppData\Local\Temp\ipykernel_12356\2841476315.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   CorMatrix = df_traton.corr()
# <AxesSubplot: >
